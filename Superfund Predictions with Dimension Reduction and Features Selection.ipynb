# %% [markdown]
# ## Import and cleaning the Census data

# %%
# Loading neccessary libraries
import pandas as pd
from sklearn.feature_selection import VarianceThreshold
import numpy as np
from numpy import mean
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import SVMSMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import ADASYN
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# Import Census data from local machine
sf_tract = pd.read_csv('C:/Datasets/pdb_tract.csv')

# %%
sf_tract.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74021 entries, 0 to 74020
# Data columns (total 567 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   FIPS_Tract                        int64
#  1   State                             int64
#  2   State_name                        object
#  3   County                            int64
#  4   County_name                       object
#  5   Tract                             int64
#  6   Flag                              float64
#  7   Num_BGs_in_Tract                  float64
#  8   LAND_AREA                         float64
#  9   AIAN_LAND                         float64
#  10  URBANIZED_AREA_POP_CEN_2010       float64
#  11  URBAN_CLUSTER_POP_CEN_2010        float64
#  12  RURAL_POP_CEN_2010                float64
#  13  Tot_Population_CEN_2010           float64
#  14  Tot_Population_ACS_09_13          float64
#  15  Tot_Population_ACSMOE_09_13       float64
#  16  Males_CEN_2010                    float64
#  17  Males_ACS_09_13                   float64
#  18  Males_ACSMOE_09_13                float64
#  19  Females_CEN_2010                  float64
#  20  Females_ACS_09_13                 float64
#  21  Females_ACSMOE_09_13              float64
#  22  Pop_under_5_CEN_2010              float64
#  23  Pop_under_5_ACS_09_13             float64
#  24  Pop_under_5_ACSMOE_09_13          float64
#  25  Pop_5_17_CEN_2010                 float64
#  26  Pop_5_17_ACS_09_13                float64
#  27  Pop_5_17_ACSMOE_09_13             float64
#  28  Pop_18_24_CEN_2010                float64
#  29  Pop_18_24_ACS_09_13               float64
#  30  Pop_18_24_ACSMOE_09_13            float64
#  31  Pop_25_44_CEN_2010                float64
#  32  Pop_25_44_ACS_09_13               float64
#  33  Pop_25_44_ACSMOE_09_13            float64
#  34  Pop_45_64_CEN_2010                float64
#  35  Pop_45_64_ACS_09_13               float64
#  36  Pop_45_64_ACSMOE_09_13            float64
#  37  Pop_65plus_CEN_2010               float64
#  38  Pop_65plus_ACS_09_13              float64
#  39  Pop_65plus_ACSMOE_09_13           float64
#  40  Tot_GQ_CEN_2010                   float64
#  41  Inst_GQ_CEN_2010                  float64
#  42  Non_Inst_GQ_CEN_2010              float64
#  43  Hispanic_CEN_2010                 float64
#  44  Hispanic_ACS_09_13                float64
#  45  Hispanic_ACSMOE_09_13             float64
#  46  NH_White_alone_CEN_2010           float64
#  47  NH_White_alone_ACS_09_13          float64
#  48  NH_White_alone_ACSMOE_09_13       float64
#  49  NH_Blk_alone_CEN_2010             float64
#  50  NH_Blk_alone_ACS_09_13            float64
#  51  NH_Blk_alone_ACSMOE_09_13         float64
#  52  NH_AIAN_alone_CEN_2010            float64
#  53  NH_AIAN_alone_ACS_09_13           float64
#  54  NH_AIAN_alone_ACSMOE_09_13        float64
#  55  NH_Asian_alone_CEN_2010           float64
#  56  NH_Asian_alone_ACS_09_13          float64
#  57  NH_Asian_alone_ACSMOE_09_13       float64
#  58  NH_NHOPI_alone_CEN_2010           float64
#  59  NH_NHOPI_alone_ACS_09_13          float64
#  60  NH_NHOPI_alone_ACSMOE_09_13       float64
#  61  NH_SOR_alone_CEN_2010             float64
#  62  NH_SOR_alone_ACS_09_13            float64
#  63  NH_SOR_alone_ACSMOE_09_13         float64
#  64  Pop_5yrs_Over_ACS_09_13           float64
#  65  Pop_5yrs_Over_ACSMOE_09_13        float64
#  66  Othr_Lang_ACS_09_13               float64
#  67  Othr_Lang_ACSMOE_09_13            float64
#  68  Age5p_Only_English_ACS_09_13      float64
#  69  Age5p_Only_English_ACSMOE_09_13   float64
#  70  Age5p_Spanish_ACS_09_13           float64
#  71  Age5p_Spanish_ACSMOE_09_13        float64
#  72  Age5p_French_ACS_09_13            float64
#  73  Age5p_French_ACSMOE_09_13         float64
#  74  Age5p_FrCreole_ACS_09_13          float64
#  75  Age5p_FrCreole_ACSMOE_09_13       float64
#  76  Age5p_Italian_ACS_09_13           float64
#  77  Age5p_Italian_ACSMOE_09_13        float64
#  78  Age5p_Portuguese_ACS_09_13        float64
#  79  Age5p_Portuguese_ACSMOE_09_13     float64
#  80  Age5p_German_ACS_09_13            float64
#  81  Age5p_German_ACSMOE_09_13         float64
#  82  Age5p_Yiddish_ACS_09_13           float64
#  83  Age5p_Yiddish_ACSMOE_09_13        float64
#  84  Age5p_WGerman_ACS_09_13           float64
#  85  Age5p_WGerman_ACSMOE_09_13        float64
#  86  Age5p_Scandinavian_ACS_09_13      float64
#  87  Age5p_Scandinavian_ACSMOE_09_13   float64
#  88  Age5p_Greek_ACS_09_13             float64
#  89  Age5p_Greek_ACSMOE_09_13          float64
#  90  Age5p_Russian_ACS_09_13           float64
#  91  Age5p_Russian_ACSMOE_09_13        float64
#  92  Age5p_Polish_ACS_09_13            float64
#  93  Age5p_Polish_ACSMOE_09_13         float64
#  94  Age5p_SRBCroatian_ACS_09_13       float64
#  95  Age5p_SRBCroatian_ACSMOE_09_13    float64
#  96  Age5p_OthSlavic_ACS_09_13         float64
#  97  Age5p_OthSlavic_ACSMOE_09_13      float64
#  98  Age5p_Armenian_ACS_09_13          float64
#  99  Age5p_Armenian_ACSMOE_09_13       float64
#  100 Age5p_Persian_ACS_09_13           float64
#  101 Age5p_Persian_ACSMOE_09_13        float64
#  102 Age5p_Gujarati_ACS_09_13          float64
#  103 Age5p_Gujarati_ACSMOE_09_13       float64
#  104 Age5p_Hindi_ACS_09_13             float64
#  105 Age5p_Hindi_ACSMOE_09_13          float64
#  106 Age5p_Urdu_ACS_09_13              float64
#  107 Age5p_Urdu_ACSMOE_09_13           float64
#  108 Age5p_OthIndic_ACS_09_13          float64
#  109 Age5p_OthIndic_ACSMOE_09_13       float64
#  110 Age5p_OthEuro_ACS_09_13           float64
#  111 Age5p_OthEuro_ACSMOE_09_13        float64
#  112 Age5p_Chinese_ACS_09_13           float64
#  113 Age5p_Chinese_ACSMOE_09_13        float64
#  114 Age5p_Japanese_ACS_09_13          float64
#  115 Age5p_Japanese_ACSMOE_09_13       float64
#  116 Age5p_Korean_ACS_09_13            float64
#  117 Age5p_Korean_ACSMOE_09_13         float64
#  118 Age5p_Cambodian_ACS_09_13         float64
#  119 Age5p_Cambodian_ACSMOE_09_13      float64
#  120 Age5p_Hmong_ACS_09_13             float64
#  121 Age5p_Hmong_ACSMOE_09_13          float64
#  122 Age5p_Thai_ACS_09_13              float64
#  123 Age5p_Thai_ACSMOE_09_13           float64
#  124 Age5p_Laotian_ACS_09_13           float64
#  125 Age5p_Laotian_ACSMOE_09_13        float64
#  126 Age5p_Vietnamese_ACS_09_13        float64
#  127 Age5p_Vietnamese_ACSMOE_09_13     float64
#  128 Age5p_OthAsian_ACS_09_13          float64
#  129 Age5p_OthAsian_ACSMOE_09_13       float64
#  130 Age5p_Tagalog_ACS_09_13           float64
#  131 Age5p_Tagalog_ACSMOE_09_13        float64
#  132 Age5p_OthPacIsl_ACS_09_13         float64
#  133 Age5p_OthPacIsl_ACSMOE_09_13      float64
#  134 Age5p_Navajo_ACS_09_13            float64
#  135 Age5p_Navajo_ACSMOE_09_13         float64
#  136 Age5p_NativeNAm_ACS_09_13         float64
#  137 Age5p_NativeNAm_ACSMOE_09_13      float64
#  138 Age5p_Hungarian_ACS_09_13         float64
#  139 Age5p_Hungarian_ACSMOE_09_13      float64
#  140 Age5p_Arabic_ACS_09_13            float64
#  141 Age5p_Arabic_ACSMOE_09_13         float64
#  142 Age5p_Hebrew_ACS_09_13            float64
#  143 Age5p_Hebrew_ACSMOE_09_13         float64
#  144 Age5p_African_ACS_09_13           float64
#  145 Age5p_African_ACSMOE_09_13        float64
#  146 Age5p_OthUnSp_ACS_09_13           float64
#  147 Age5p_OthUnSp_ACSMOE_09_13        float64
#  148 Pop_25yrs_Over_ACS_09_13          float64
#  149 Pop_25yrs_Over_ACSMOE_09_13       float64
#  150 Not_HS_Grad_ACS_09_13             float64
#  151 Not_HS_Grad_ACSMOE_09_13          float64
#  152 College_ACS_09_13                 float64
#  153 College_ACSMOE_09_13              float64
#  154 Pov_Univ_ACS_09_13                float64
#  155 Pov_Univ_ACSMOE_09_13             float64
#  156 Prs_Blw_Pov_Lev_ACS_09_13         float64
#  157 Prs_Blw_Pov_Lev_ACSMOE_09_13      float64
#  158 One_Health_Ins_ACS_09_13          float64
#  159 One_Health_Ins_ACSMOE_09_13       float64
#  160 Two_Plus_Health_Ins_ACS_09_13     float64
#  161 Two_Plus_Health_Ins_ACSMOE_09_13  float64
#  162 No_Health_Ins_ACS_09_13           float64
#  163 No_Health_Ins_ACSMOE_09_13        float64
#  164 Civ_labor_16plus_ACS_09_13        float64
#  165 Civ_labor_16plus_ACSMOE_09_13     float64
#  166 Civ_emp_16plus_ACS_09_13          float64
#  167 Civ_emp_16plus_ACSMOE_09_13       float64
#  168 Civ_unemp_16plus_ACS_09_13        float64
#  169 Civ_unemp_16plus_ACSMOE_09_13     float64
#  170 Civ_labor_16_24_ACS_09_13         float64
#  171 Civ_labor_16_24_ACSMOE_09_13      float64
#  172 Civ_emp_16_24_ACS_09_13           float64
#  173 Civ_emp_16_24_ACSMOE_09_13        float64
#  174 Civ_unemp_16_24_ACS_09_13         float64
#  175 Civ_unemp_16_24_ACSMOE_09_13      float64
#  176 Civ_labor_25_44_ACS_09_13         float64
#  177 Civ_labor_25_44_ACSMOE_09_13      float64
#  178 Civ_emp_25_44_ACS_09_13           float64
#  179 Civ_emp_25_44_ACSMOE_09_13        float64
#  180 Civ_unemp_25_44_ACS_09_13         float64
#  181 Civ_unemp_25_44_ACSMOE_09_13      float64
#  182 Civ_labor_45_64_ACS_09_13         float64
#  183 Civ_labor_45_64_ACSMOE_09_13      float64
#  184 Civ_emp_45_64_ACS_09_13           float64
#  185 Civ_emp_45_64_ACSMOE_09_13        float64
#  186 Civ_unemp_45_64_ACS_09_13         float64
#  187 Civ_unemp_45_64_ACSMOE_09_13      float64
#  188 Civ_labor_65plus_ACS_09_13        float64
#  189 Civ_labor_65plus_ACSMOE_09_13     float64
#  190 Civ_emp_65plus_ACS_09_13          float64
#  191 Civ_emp_65plus_ACSMOE_09_13       float64
#  192 Civ_unemp_65plus_ACS_09_13        float64
#  193 Civ_unemp_65plus_ACSMOE_09_13     float64
#  194 Pop_1yr_Over_ACS_09_13            float64
#  195 Pop_1yr_Over_ACSMOE_09_13         float64
#  196 Diff_HU_1yr_Ago_ACS_09_13         float64
#  197 Diff_HU_1yr_Ago_ACSMOE_09_13      float64
#  198 Born_US_ACS_09_13                 float64
#  199 Born_US_ACSMOE_09_13              float64
#  200 Born_foreign_ACS_09_13            float64
#  201 Born_foreign_ACSMOE_09_13         float64
#  202 US_Cit_Nat_ACS_09_13              float64
#  203 US_Cit_Nat_ACSMOE_09_13           float64
#  204 NON_US_Cit_ACS_09_13              float64
#  205 NON_US_Cit_ACSMOE_09_13           float64
#  206 ENG_VW_SPAN_ACS_09_13             float64
#  207 ENG_VW_SPAN_ACSMOE_09_13          float64
#  208 ENG_VW_INDO_EURO_ACS_09_13        float64
#  209 ENG_VW_INDO_EURO_ACSMOE_09_13     float64
#  210 ENG_VW_API_ACS_09_13              float64
#  211 ENG_VW_API_ACSMOE_09_13           float64
#  212 ENG_VW_OTHER_ACS_09_13            float64
#  213 ENG_VW_OTHER_ACSMOE_09_13         float64
#  214 ENG_VW_ACS_09_13                  float64
#  215 ENG_VW_ACSMOE_09_13               float64
#  216 Rel_Family_HHDS_CEN_2010          float64
#  217 Rel_Family_HHD_ACS_09_13          float64
#  218 Rel_Family_HHD_ACSMOE_09_13       float64
#  219 MrdCple_Fmly_HHD_CEN_2010         float64
#  220 MrdCple_Fmly_HHD_ACS_09_13        float64
#  221 MrdCple_Fmly_HHD_ACSMOE_09_13     float64
#  222 Not_MrdCple_HHD_CEN_2010          float64
#  223 Not_MrdCple_HHD_ACS_09_13         float64
#  224 Not_MrdCple_HHD_ACSMOE_09_13      float64
#  225 Female_No_HB_CEN_2010             float64
#  226 Female_No_HB_ACS_09_13            float64
#  227 Female_No_HB_ACSMOE_09_13         float64
#  228 NonFamily_HHD_CEN_2010            float64
#  229 NonFamily_HHD_ACS_09_13           float64
#  230 NonFamily_HHD_ACSMOE_09_13        float64
#  231 Sngl_Prns_HHD_CEN_2010            float64
#  232 Sngl_Prns_HHD_ACS_09_13           float64
#  233 Sngl_Prns_HHD_ACSMOE_09_13        float64
#  234 HHD_PPL_Und_18_CEN_2010           float64
#  235 HHD_PPL_Und_18_ACS_09_13          float64
#  236 HHD_PPL_Und_18_ACSMOE_09_13       float64
#  237 Tot_Prns_in_HHD_CEN_2010          float64
#  238 Tot_Prns_in_HHD_ACS_09_13         float64
#  239 Tot_Prns_in_HHD_ACSMOE_09_13      float64
#  240 Rel_Child_Under_6_CEN_2010        float64
#  241 Rel_Child_Under_6_ACS_09_13       float64
#  242 Rel_Child_Under_6_ACSMOE_09_13    float64
#  243 HHD_Moved_in_ACS_09_13            float64
#  244 HHD_Moved_in_ACSMOE_09_13         float64
#  245 PUB_ASST_INC_ACS_09_13            float64
#  246 PUB_ASST_INC_ACSMOE_09_13         float64
#  247 Med_HHD_Inc_ACS_09_13             object
#  248 Med_HHD_Inc_ACSMOE_09_13          object
#  249 Aggregate_HH_INC_ACS_09_13        object
#  250 Aggregate_HH_INC_ACSMOE_09_13     object
#  251 Tot_Housing_Units_CEN_2010        float64
#  252 Tot_Housing_Units_ACS_09_13       float64
#  253 Tot_Housing_Units_ACSMOE_09_13    float64
#  254 Tot_Occp_Units_CEN_2010           float64
#  255 Tot_Occp_Units_ACS_09_13          float64
#  256 Tot_Occp_Units_ACSMOE_09_13       float64
#  257 Tot_Vacant_Units_CEN_2010         float64
#  258 Tot_Vacant_Units_ACS_09_13        float64
#  259 Tot_Vacant_Units_ACSMOE_09_13     float64
#  260 Renter_Occp_HU_CEN_2010           float64
#  261 Renter_Occp_HU_ACS_09_13          float64
#  262 Renter_Occp_HU_ACSMOE_09_13       float64
#  263 Owner_Occp_HU_CEN_2010            float64
#  264 Owner_Occp_HU_ACS_09_13           float64
#  265 Owner_Occp_HU_ACSMOE_09_13        float64
#  266 Single_Unit_ACS_09_13             float64
#  267 Single_Unit_ACSMOE_09_13          float64
#  268 MLT_U2_9_STRC_ACS_09_13           float64
#  269 MLT_U2_9_STRC_ACSMOE_09_13        float64
#  270 MLT_U10p_ACS_09_13                float64
#  271 MLT_U10p_ACSMOE_09_13             float64
#  272 Mobile_Homes_ACS_09_13            float64
#  273 Mobile_Homes_ACSMOE_09_13         float64
#  274 Crowd_Occp_U_ACS_09_13            float64
#  275 Crowd_Occp_U_ACSMOE_09_13         float64
#  276 Occp_U_NO_PH_SRVC_ACS_09_13       float64
#  277 Occp_U_NO_PH_SRVC_ACSMOE_09_13    float64
#  278 No_Plumb_ACS_09_13                float64
#  279 No_Plumb_ACSMOE_09_13             float64
#  280 Recent_Built_HU_ACS_09_13         float64
#  281 Recent_Built_HU_ACSMOE_09_13      float64
#  282 Med_House_value_ACS_09_13         object
#  283 Med_House_value_ACSMOE_09_13      object
#  284 Aggr_House_Value_ACS_09_13        object
#  285 Aggr_House_Value_ACSMOE_09_13     object
#  286 MailBack_Area_Count_CEN_2010      float64
#  287 TEA_Mail_Out_Mail_Back_CEN_2010   float64
#  288 TEA_Update_Leave_CEN_2010         float64
#  289 Census_Mail_Returns_CEN_2010      float64
#  290 Vacants_CEN_2010                  float64
#  291 Deletes_CEN_2010                  float64
#  292 Census_UAA_CEN_2010               float64
#  293 Valid_Mailback_Count_CEN_2010     float64
#  294 FRST_FRMS_CEN_2010                float64
#  295 RPLCMNT_FRMS_CEN_2010             float64
#  296 BILQ_Mailout_count_CEN_2010       float64
#  297 BILQ_Frms_CEN_2010                float64
#  298 Mail_Return_Rate_CEN_2010         float64
#  299 Low_Response_Score                float64
#  300 pct_URBANIZED_AREA_POP_CEN_2010   float64
#  301 pct_URBAN_CLUSTER_POP_CEN_2010    float64
#  302 pct_RURAL_POP_CEN_2010            float64
#  303 pct_Males_CEN_2010                float64
#  304 pct_Males_ACS_09_13               float64
#  305 pct_Males_ACSMOE_09_13            float64
#  306 pct_Females_CEN_2010              float64
#  307 pct_Females_ACS_09_13             float64
#  308 pct_Females_ACSMOE_09_13          float64
#  309 pct_Pop_Under_5_CEN_2010          float64
#  310 pct_Pop_Under_5_ACS_09_13         float64
#  311 pct_Pop_Under_5_ACSMOE_09_13      float64
#  312 pct_Pop_5_17_CEN_2010             float64
#  313 pct_Pop_5_17_ACS_09_13            float64
#  314 pct_Pop_5_17_ACSMOE_09_13         float64
#  315 pct_Pop_18_24_CEN_2010            float64
#  316 pct_Pop_18_24_ACS_09_13           float64
#  317 pct_Pop_18_24_ACSMOE_09_13        float64
#  318 pct_Pop_25_44_CEN_2010            float64
#  319 pct_Pop_25_44_ACS_09_13           float64
#  320 pct_Pop_25_44_ACSMOE_09_13        float64
#  321 pct_Pop_45_64_CEN_2010            float64
#  322 pct_Pop_45_64_ACS_09_13           float64
#  323 pct_Pop_45_64_ACSMOE_09_13        float64
#  324 pct_Pop_65plus_CEN_2010           float64
#  325 pct_Pop_65plus_ACS_09_13          float64
#  326 pct_Pop_65plus_ACSMOE_09_13       float64
#  327 pct_Tot_GQ_CEN_2010               float64
#  328 pct_Inst_GQ_CEN_2010              float64
#  329 pct_Non_Inst_GQ_CEN_2010          float64
#  330 pct_Hispanic_CEN_2010             float64
#  331 pct_Hispanic_ACS_09_13            float64
#  332 pct_Hispanic_ACSMOE_09_13         float64
#  333 pct_NH_White_alone_CEN_2010       float64
#  334 pct_NH_White_alone_ACS_09_13      float64
#  335 pct_NH_White_alone_ACSMOE_09_13   float64
#  336 pct_NH_Blk_alone_CEN_2010         float64
#  337 pct_NH_Blk_alone_ACS_09_13        float64
#  338 pct_NH_Blk_alone_ACSMOE_09_13     float64
#  339 pct_NH_AIAN_alone_CEN_2010        float64
#  340 pct_NH_AIAN_alone_ACS_09_13       float64
#  341 pct_NH_AIAN_alone_ACSMOE_09_13    float64
#  342 pct_NH_Asian_alone_CEN_2010       float64
#  343 pct_NH_Asian_alone_ACS_09_13      float64
#  344 pct_NH_Asian_alone_ACSMOE_09_13   float64
#  345 pct_NH_NHOPI_alone_CEN_2010       float64
#  346 pct_NH_NHOPI_alone_ACS_09_13      float64
#  347 pct_NH_NHOPI_alone_ACSMOE_09_13   float64
#  348 pct_NH_SOR_alone_CEN_2010         float64
#  349 pct_NH_SOR_alone_ACS_09_13        float64
#  350 pct_NH_SOR_alone_ACSMOE_09_13     float64
#  351 pct_Pop_5yrs_Over_ACS_09_13       float64
#  352 pct_Pop_5yrs_Over_ACSMOE_09_13    float64
#  353 pct_Othr_Lang_ACS_09_13           float64
#  354 pct_Othr_Lang_ACSMOE_09_13        float64
#  355 pct_Age5p_Only_Eng_ACS_09_13      float64
#  356 pct_Age5p_Only_Eng_ACSMOE_09_13   float64
#  357 pct_Age5p_Spanish_ACS_09_13       float64
#  358 pct_Age5p_Spanish_ACSMOE_09_13    float64
#  359 pct_Age5p_French_ACS_09_13        float64
#  360 pct_Age5p_French_ACSMOE_09_13     float64
#  361 pct_Age5p_FrCreole_ACS_09_13      float64
#  362 pct_Age5p_FrCreole_ACSMOE_09_13   float64
#  363 pct_Age5p_Italian_ACS_09_13       float64
#  364 pct_Age5p_Italian_ACSMOE_09_13    float64
#  365 pct_Age5p_Portugues_ACS_09_13     float64
#  366 pct_Age5p_Portugues_ACSMOE_09_13  float64
#  367 pct_Age5p_German_ACS_09_13        float64
#  368 pct_Age5p_German_ACSMOE_09_13     float64
#  369 pct_Age5p_Yiddish_ACS_09_13       float64
#  370 pct_Age5p_Yiddish_ACSMOE_09_13    float64
#  371 pct_Age5p_WGerman_ACS_09_13       float64
#  372 pct_Age5p_WGerman_ACSMOE_09_13    float64
#  373 pct_Age5p_Scandinav_ACS_09_13     float64
#  374 pct_Age5p_Scandinav_ACSMOE_09_13  float64
#  375 pct_Age5p_Greek_ACS_09_13         float64
#  376 pct_Age5p_Greek_ACSMOE_09_13      float64
#  377 pct_Age5p_Russian_ACS_09_13       float64
#  378 pct_Age5p_Russian_ACSMOE_09_13    float64
#  379 pct_Age5p_Polish_ACS_09_13        float64
#  380 pct_Age5p_Polish_ACSMOE_09_13     float64
#  381 pct_Age5p_SRBCroati_ACS_09_13     float64
#  382 pct_Age5p_SRBCroati_ACSMOE_09_13  float64
#  383 pct_Age5p_OthSlavic_ACS_09_13     float64
#  384 pct_Age5p_OthSlavic_ACSMOE_09_13  float64
#  385 pct_Age5p_Armenian_ACS_09_13      float64
#  386 pct_Age5p_Armenian_ACSMOE_09_13   float64
#  387 pct_Age5p_Persian_ACS_09_13       float64
#  388 pct_Age5p_Persian_ACSMOE_09_13    float64
#  389 pct_Age5p_Gujarati_ACS_09_13      float64
#  390 pct_Age5p_Gujarati_ACSMOE_09_13   float64
#  391 pct_Age5p_Hindi_ACS_09_13         float64
#  392 pct_Age5p_Hindi_ACSMOE_09_13      float64
#  393 pct_Age5p_Urdu_ACS_09_13          float64
#  394 pct_Age5p_Urdu_ACSMOE_09_13       float64
#  395 pct_Age5p_OthIndic_ACS_09_13      float64
#  396 pct_Age5p_OthIndic_ACSMOE_09_13   float64
#  397 pct_Age5p_OthEuro_ACS_09_13       float64
#  398 pct_Age5p_OthEuro_ACSMOE_09_13    float64
#  399 pct_Age5p_Chinese_ACS_09_13       float64
#  400 pct_Age5p_Chinese_ACSMOE_09_13    float64
#  401 pct_Age5p_Japanese_ACS_09_13      float64
#  402 pct_Age5p_Japanese_ACSMOE_09_13   float64
#  403 pct_Age5p_Korean_ACS_09_13        float64
#  404 pct_Age5p_Korean_ACSMOE_09_13     float64
#  405 pct_Age5p_Cambodian_ACS_09_13     float64
#  406 pct_Age5p_Cambodian_ACSMOE_09_13  float64
#  407 pct_Age5p_Hmong_ACS_09_13         float64
#  408 pct_Age5p_Hmong_ACSMOE_09_13      float64
#  409 pct_Age5p_Thai_ACS_09_13          float64
#  410 pct_Age5p_Thai_ACSMOE_09_13       float64
#  411 pct_Age5p_Laotian_ACS_09_13       float64
#  412 pct_Age5p_Laotian_ACSMOE_09_13    float64
#  413 pct_Age5p_Vietnames_ACS_09_13     float64
#  414 pct_Age5p_Vietnames_ACSMOE_09_13  float64
#  415 pct_Age5p_OthAsian_ACS_09_13      float64
#  416 pct_Age5p_OthAsian_ACSMOE_09_13   float64
#  417 pct_Age5p_Tagalog_ACS_09_13       float64
#  418 pct_Age5p_Tagalog_ACSMOE_09_13    float64
#  419 pct_Age5p_OthPacIsl_ACS_09_13     float64
#  420 pct_Age5p_OthPacIsl_ACSMOE_09_13  float64
#  421 pct_Age5p_Navajo_ACS_09_13        float64
#  422 pct_Age5p_Navajo_ACSMOE_09_13     float64
#  423 pct_Age5p_NativeNAm_ACS_09_13     float64
#  424 pct_Age5p_NativeNAm_ACSMOE_09_13  float64
#  425 pct_Age5p_Hungarian_ACS_09_13     float64
#  426 pct_Age5p_Hungarian_ACSMOE_09_13  float64
#  427 pct_Age5p_Arabic_ACS_09_13        float64
#  428 pct_Age5p_Arabic_ACSMOE_09_13     float64
#  429 pct_Age5p_Hebrew_ACS_09_13        float64
#  430 pct_Age5p_Hebrew_ACSMOE_09_13     float64
#  431 pct_Age5p_African_ACS_09_13       float64
#  432 pct_Age5p_African_ACSMOE_09_13    float64
#  433 pct_Age5p_OthUnSp_ACS_09_13       float64
#  434 pct_Age5p_OthUnSp_ACSMOE_09_13    float64
#  435 pct_Pop_25yrs_Over_ACS_09_13      float64
#  436 pct_Pop_25yrs_Over_ACSMOE_09_13   float64
#  437 pct_Not_HS_Grad_ACS_09_13         float64
#  438 pct_Not_HS_Grad_ACSMOE_09_13      float64
#  439 pct_College_ACS_09_13             float64
#  440 pct_College_ACSMOE_09_13          float64
#  441 pct_Pov_Univ_ACS_09_13            float64
#  442 pct_Pov_Univ_ACSMOE_09_13         float64
#  443 pct_Prs_Blw_Pov_Lev_ACS_09_13     float64
#  444 pct_Prs_Blw_Pov_Lev_ACSMOE_09_13  float64
#  445 pct_One_Health_Ins_ACS_09_13      float64
#  446 pct_One_Health_Ins_ACSMOE_09_13   float64
#  447 pct_TwoPHealth_Ins_ACS_09_13      float64
#  448 pct_TwoPHealthIns_ACSMOE_09_13    float64
#  449 pct_No_Health_Ins_ACS_09_13       float64
#  450 pct_No_Health_Ins_ACSMOE_09_13    float64
#  451 pct_Civ_emp_16p_ACS_09_13         float64
#  452 pct_Civ_emp_16p_ACSMOE_09_13      float64
#  453 pct_Civ_unemp_16p_ACS_09_13       float64
#  454 pct_Civ_unemp_16p_ACSMOE_09_13    float64
#  455 pct_Civ_emp_16_24_ACS_09_13       float64
#  456 pct_Civ_emp_16_24_ACSMOE_09_13    float64
#  457 pct_Civ_unemp_16_24_ACS_09_13     float64
#  458 pct_Civ_unemp_16_24_ACSMOE_09_13  float64
#  459 pct_Civ_emp_25_44_ACS_09_13       float64
#  460 pct_Civ_emp_25_44_ACSMOE_09_13    float64
#  461 pct_Civ_unemp_25_44_ACS_09_13     float64
#  462 pct_Civ_unemp_25_44_ACSMOE_09_13  float64
#  463 pct_Civ_emp_45_64_ACS_09_13       float64
#  464 pct_Civ_emp_45_64_ACSMOE_09_13    float64
#  465 pct_Civ_unemp_45_64_ACS_09_13     float64
#  466 pct_Civ_unemp_45_64_ACSMOE_09_13  float64
#  467 pct_Civ_emp_65p_ACS_09_13         float64
#  468 pct_Civ_emp_65p_ACSMOE_09_13      float64
#  469 pct_Civ_unemp_65p_ACS_09_13       float64
#  470 pct_Civ_unemp_65p_ACSMOE_09_13    float64
#  471 pct_Pop_1yr_Over_ACS_09_13        float64
#  472 pct_Pop_1yr_Over_ACSMOE_09_13     float64
#  473 pct_Diff_HU_1yr_Ago_ACS_09_13     float64
#  474 pct_Diff_HU_1yr_Ago_ACSMOE_09_13  float64
#  475 pct_Born_US_ACS_09_13             float64
#  476 pct_Born_US_ACSMOE_09_13          float64
#  477 pct_Born_foreign_ACS_09_13        float64
#  478 pct_Born_foreign_ACSMOE_09_13     float64
#  479 pct_US_Cit_Nat_ACS_09_13          float64
#  480 pct_US_Cit_Nat_ACSMOE_09_13       float64
#  481 pct_NON_US_Cit_ACS_09_13          float64
#  482 pct_NON_US_Cit_ACSMOE_09_13       float64
#  483 pct_ENG_VW_SPAN_ACS_09_13         float64
#  484 pct_ENG_VW_SPAN_ACSMOE_09_13      float64
#  485 pct_ENG_VW_INDOEURO_ACS_09_13     float64
#  486 pct_ENG_VW_INDOEURO_ACSMOE_09_13  float64
#  487 pct_ENG_VW_API_ACS_09_13          float64
#  488 pct_ENG_VW_API_ACSMOE_09_13       float64
#  489 pct_ENG_VW_OTHER_ACS_09_13        float64
#  490 pct_ENG_VW_OTHER_ACSMOE_09_13     float64
#  491 pct_ENG_VW_ACS_09_13              float64
#  492 pct_ENG_VW_ACSMOE_09_13           float64
#  493 pct_Rel_Family_HHDS_CEN_2010      float64
#  494 pct_Rel_Family_HHD_ACS_09_13      float64
#  495 pct_Rel_Family_HHD_ACSMOE_09_13   float64
#  496 pct_MrdCple_HHD_CEN_2010          float64
#  497 pct_MrdCple_HHD_ACS_09_13         float64
#  498 pct_MrdCple_HHD_ACSMOE_09_13      float64
#  499 pct_Not_MrdCple_HHD_CEN_2010      float64
#  500 pct_Not_MrdCple_HHD_ACS_09_13     float64
#  501 pct_Not_MrdCple_HHD_ACSMOE_09_13  float64
#  502 pct_Female_No_HB_CEN_2010         float64
#  503 pct_Female_No_HB_ACS_09_13        float64
#  504 pct_Female_No_HB_ACSMOE_09_13     float64
#  505 pct_NonFamily_HHD_CEN_2010        float64
#  506 pct_NonFamily_HHD_ACS_09_13       float64
#  507 pct_NonFamily_HHD_ACSMOE_09_13    float64
#  508 pct_Sngl_Prns_HHD_CEN_2010        float64
#  509 pct_Sngl_Prns_HHD_ACS_09_13       float64
#  510 pct_Sngl_Prns_HHD_ACSMOE_09_13    float64
#  511 pct_HHD_PPL_Und_18_CEN_2010       float64
#  512 pct_HHD_PPL_Und_18_ACS_09_13      float64
#  513 pct_HHD_PPL_Und_18_ACSMOE_09_13   float64
#  514 avg_Tot_Prns_in_HHD_CEN_2010      float64
#  515 avg_Tot_Prns_in_HHD_ACS_09_13     float64
#  516 avg_Tot_Prns_in_HHD_ACSMOE_09_13  float64
#  517 pct_Rel_Under_6_CEN_2010          float64
#  518 pct_Rel_Under_6_ACS_09_13         float64
#  519 pct_Rel_Under_6_ACSMOE_09_13      float64
#  520 pct_HHD_Moved_in_ACS_09_13        float64
#  521 pct_HHD_Moved_in_ACSMOE_09_13     float64
#  522 pct_PUB_ASST_INC_ACS_09_13        float64
#  523 pct_PUB_ASST_INC_ACSMOE_09_13     float64
#  524 avg_Agg_HH_INC_ACS_09_13          object
#  525 avg_Agg_HH_INC_ACSMOE_09_13       object
#  526 pct_Tot_Occp_Units_CEN_2010       float64
#  527 pct_Tot_Occp_Units_ACS_09_13      float64
#  528 pct_Tot_Occp_Units_ACSMOE_09_13   float64
#  529 pct_Vacant_Units_CEN_2010         float64
#  530 pct_Vacant_Units_ACS_09_13        float64
#  531 pct_Vacant_Units_ACSMOE_09_13     float64
#  532 pct_Renter_Occp_HU_CEN_2010       float64
#  533 pct_Renter_Occp_HU_ACS_09_13      float64
#  534 pct_Renter_Occp_HU_ACSMOE_09_13   float64
#  535 pct_Owner_Occp_HU_CEN_2010        float64
#  536 pct_Owner_Occp_HU_ACS_09_13       float64
#  537 pct_Owner_Occp_HU_ACSMOE_09_13    float64
#  538 pct_Single_Unit_ACS_09_13         float64
#  539 pct_Single_Unit_ACSMOE_09_13      float64
#  540 pct_MLT_U2_9_STRC_ACS_09_13       float64
#  541 pct_MLT_U2_9_STRC_ACSMOE_09_13    float64
#  542 pct_MLT_U10p_ACS_09_13            float64
#  543 pct_MLT_U10p_ACSMOE_09_13         float64
#  544 pct_Mobile_Homes_ACS_09_13        float64
#  545 pct_Mobile_Homes_ACSMOE_09_13     float64
#  546 pct_Crowd_Occp_U_ACS_09_13        float64
#  547 pct_Crowd_Occp_U_ACSMOE_09_13     float64
#  548 pct_NO_PH_SRVC_ACS_09_13          float64
#  549 pct_NO_PH_SRVC_ACSMOE_09_13       float64
#  550 pct_No_Plumb_ACS_09_13            float64
#  551 pct_No_Plumb_ACSMOE_09_13         float64
#  552 pct_Recent_Built_HU_ACS_09_13     float64
#  553 pct_Recent_Built_HU_ACSMOE_09_13  float64
#  554 avg_Agg_House_Value_ACS_09_13     object
#  555 avg_Agg_House_Value_ACSMOE_09_13  object
#  556 pct_TEA_MailOutMailBack_CEN_2010  float64
#  557 pct_TEA_Update_Leave_CEN_2010     float64
#  558 pct_Census_Mail_Returns_CEN_2010  float64
#  559 pct_Vacant_CEN_2010               float64
#  560 pct_Deletes_CEN_2010              float64
#  561 pct_Census_UAA_CEN_2010           float64
#  562 pct_Mailback_Count_CEN_2010       float64
#  563 pct_FRST_FRMS_CEN_2010            float64
#  564 pct_RPLCMNT_FRMS_CEN_2010         float64
#  565 pct_BILQ_Mailout_count_CEN_2010   float64
#  566 has_superfund                     int64
# dtypes: float64(548), int64(5), object(14)
# memory usage: 320.2+ MB

# %%
# Dropping columns cotain MOE as it is the margin of error which not needed for prediction now
sf_tract = sf_tract.drop(list(sf_tract.filter(regex='MOE')), axis=1)

# %%
# We also drop administrative data columns such as state name, county name, ... which are not useful for prediction
sf_tract = sf_tract.drop(['FIPS_Tract', 'State', 'State_name', 'County', 'County_name', 'Tract', 'Flag', 'Num_BGs_in_Tract'], axis=1)

# %%
# Filter a list of currency columns need to convert
currency_columns = list(sf_tract.select_dtypes(include='object').columns)

# %%
# Finally, convert currency to numeric value
for col in currency_columns:
    sf_tract[col] = pd.to_numeric(sf_tract[col].str.replace('$','').str.replace(',',''))

# %%
# Check that we have all as numeric values
sf_tract.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74021 entries, 0 to 74020
# Data columns (total 328 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   LAND_AREA                         float64
#  1   AIAN_LAND                         float64
#  2   URBANIZED_AREA_POP_CEN_2010       float64
#  3   URBAN_CLUSTER_POP_CEN_2010        float64
#  4   RURAL_POP_CEN_2010                float64
#  5   Tot_Population_CEN_2010           float64
#  6   Tot_Population_ACS_09_13          float64
#  7   Males_CEN_2010                    float64
#  8   Males_ACS_09_13                   float64
#  9   Females_CEN_2010                  float64
#  10  Females_ACS_09_13                 float64
#  11  Pop_under_5_CEN_2010              float64
#  12  Pop_under_5_ACS_09_13             float64
#  13  Pop_5_17_CEN_2010                 float64
#  14  Pop_5_17_ACS_09_13                float64
#  15  Pop_18_24_CEN_2010                float64
#  16  Pop_18_24_ACS_09_13               float64
#  17  Pop_25_44_CEN_2010                float64
#  18  Pop_25_44_ACS_09_13               float64
#  19  Pop_45_64_CEN_2010                float64
#  20  Pop_45_64_ACS_09_13               float64
#  21  Pop_65plus_CEN_2010               float64
#  22  Pop_65plus_ACS_09_13              float64
#  23  Tot_GQ_CEN_2010                   float64
#  24  Inst_GQ_CEN_2010                  float64
#  25  Non_Inst_GQ_CEN_2010              float64
#  26  Hispanic_CEN_2010                 float64
#  27  Hispanic_ACS_09_13                float64
#  28  NH_White_alone_CEN_2010           float64
#  29  NH_White_alone_ACS_09_13          float64
#  30  NH_Blk_alone_CEN_2010             float64
#  31  NH_Blk_alone_ACS_09_13            float64
#  32  NH_AIAN_alone_CEN_2010            float64
#  33  NH_AIAN_alone_ACS_09_13           float64
#  34  NH_Asian_alone_CEN_2010           float64
#  35  NH_Asian_alone_ACS_09_13          float64
#  36  NH_NHOPI_alone_CEN_2010           float64
#  37  NH_NHOPI_alone_ACS_09_13          float64
#  38  NH_SOR_alone_CEN_2010             float64
#  39  NH_SOR_alone_ACS_09_13            float64
#  40  Pop_5yrs_Over_ACS_09_13           float64
#  41  Othr_Lang_ACS_09_13               float64
#  42  Age5p_Only_English_ACS_09_13      float64
#  43  Age5p_Spanish_ACS_09_13           float64
#  44  Age5p_French_ACS_09_13            float64
#  45  Age5p_FrCreole_ACS_09_13          float64
#  46  Age5p_Italian_ACS_09_13           float64
#  47  Age5p_Portuguese_ACS_09_13        float64
#  48  Age5p_German_ACS_09_13            float64
#  49  Age5p_Yiddish_ACS_09_13           float64
#  50  Age5p_WGerman_ACS_09_13           float64
#  51  Age5p_Scandinavian_ACS_09_13      float64
#  52  Age5p_Greek_ACS_09_13             float64
#  53  Age5p_Russian_ACS_09_13           float64
#  54  Age5p_Polish_ACS_09_13            float64
#  55  Age5p_SRBCroatian_ACS_09_13       float64
#  56  Age5p_OthSlavic_ACS_09_13         float64
#  57  Age5p_Armenian_ACS_09_13          float64
#  58  Age5p_Persian_ACS_09_13           float64
#  59  Age5p_Gujarati_ACS_09_13          float64
#  60  Age5p_Hindi_ACS_09_13             float64
#  61  Age5p_Urdu_ACS_09_13              float64
#  62  Age5p_OthIndic_ACS_09_13          float64
#  63  Age5p_OthEuro_ACS_09_13           float64
#  64  Age5p_Chinese_ACS_09_13           float64
#  65  Age5p_Japanese_ACS_09_13          float64
#  66  Age5p_Korean_ACS_09_13            float64
#  67  Age5p_Cambodian_ACS_09_13         float64
#  68  Age5p_Hmong_ACS_09_13             float64
#  69  Age5p_Thai_ACS_09_13              float64
#  70  Age5p_Laotian_ACS_09_13           float64
#  71  Age5p_Vietnamese_ACS_09_13        float64
#  72  Age5p_OthAsian_ACS_09_13          float64
#  73  Age5p_Tagalog_ACS_09_13           float64
#  74  Age5p_OthPacIsl_ACS_09_13         float64
#  75  Age5p_Navajo_ACS_09_13            float64
#  76  Age5p_NativeNAm_ACS_09_13         float64
#  77  Age5p_Hungarian_ACS_09_13         float64
#  78  Age5p_Arabic_ACS_09_13            float64
#  79  Age5p_Hebrew_ACS_09_13            float64
#  80  Age5p_African_ACS_09_13           float64
#  81  Age5p_OthUnSp_ACS_09_13           float64
#  82  Pop_25yrs_Over_ACS_09_13          float64
#  83  Not_HS_Grad_ACS_09_13             float64
#  84  College_ACS_09_13                 float64
#  85  Pov_Univ_ACS_09_13                float64
#  86  Prs_Blw_Pov_Lev_ACS_09_13         float64
#  87  One_Health_Ins_ACS_09_13          float64
#  88  Two_Plus_Health_Ins_ACS_09_13     float64
#  89  No_Health_Ins_ACS_09_13           float64
#  90  Civ_labor_16plus_ACS_09_13        float64
#  91  Civ_emp_16plus_ACS_09_13          float64
#  92  Civ_unemp_16plus_ACS_09_13        float64
#  93  Civ_labor_16_24_ACS_09_13         float64
#  94  Civ_emp_16_24_ACS_09_13           float64
#  95  Civ_unemp_16_24_ACS_09_13         float64
#  96  Civ_labor_25_44_ACS_09_13         float64
#  97  Civ_emp_25_44_ACS_09_13           float64
#  98  Civ_unemp_25_44_ACS_09_13         float64
#  99  Civ_labor_45_64_ACS_09_13         float64
#  100 Civ_emp_45_64_ACS_09_13           float64
#  101 Civ_unemp_45_64_ACS_09_13         float64
#  102 Civ_labor_65plus_ACS_09_13        float64
#  103 Civ_emp_65plus_ACS_09_13          float64
#  104 Civ_unemp_65plus_ACS_09_13        float64
#  105 Pop_1yr_Over_ACS_09_13            float64
#  106 Diff_HU_1yr_Ago_ACS_09_13         float64
#  107 Born_US_ACS_09_13                 float64
#  108 Born_foreign_ACS_09_13            float64
#  109 US_Cit_Nat_ACS_09_13              float64
#  110 NON_US_Cit_ACS_09_13              float64
#  111 ENG_VW_SPAN_ACS_09_13             float64
#  112 ENG_VW_INDO_EURO_ACS_09_13        float64
#  113 ENG_VW_API_ACS_09_13              float64
#  114 ENG_VW_OTHER_ACS_09_13            float64
#  115 ENG_VW_ACS_09_13                  float64
#  116 Rel_Family_HHDS_CEN_2010          float64
#  117 Rel_Family_HHD_ACS_09_13          float64
#  118 MrdCple_Fmly_HHD_CEN_2010         float64
#  119 MrdCple_Fmly_HHD_ACS_09_13        float64
#  120 Not_MrdCple_HHD_CEN_2010          float64
#  121 Not_MrdCple_HHD_ACS_09_13         float64
#  122 Female_No_HB_CEN_2010             float64
#  123 Female_No_HB_ACS_09_13            float64
#  124 NonFamily_HHD_CEN_2010            float64
#  125 NonFamily_HHD_ACS_09_13           float64
#  126 Sngl_Prns_HHD_CEN_2010            float64
#  127 Sngl_Prns_HHD_ACS_09_13           float64
#  128 HHD_PPL_Und_18_CEN_2010           float64
#  129 HHD_PPL_Und_18_ACS_09_13          float64
#  130 Tot_Prns_in_HHD_CEN_2010          float64
#  131 Tot_Prns_in_HHD_ACS_09_13         float64
#  132 Rel_Child_Under_6_CEN_2010        float64
#  133 Rel_Child_Under_6_ACS_09_13       float64
#  134 HHD_Moved_in_ACS_09_13            float64
#  135 PUB_ASST_INC_ACS_09_13            float64
#  136 Med_HHD_Inc_ACS_09_13             float64
#  137 Aggregate_HH_INC_ACS_09_13        float64
#  138 Tot_Housing_Units_CEN_2010        float64
#  139 Tot_Housing_Units_ACS_09_13       float64
#  140 Tot_Occp_Units_CEN_2010           float64
#  141 Tot_Occp_Units_ACS_09_13          float64
#  142 Tot_Vacant_Units_CEN_2010         float64
#  143 Tot_Vacant_Units_ACS_09_13        float64
#  144 Renter_Occp_HU_CEN_2010           float64
#  145 Renter_Occp_HU_ACS_09_13          float64
#  146 Owner_Occp_HU_CEN_2010            float64
#  147 Owner_Occp_HU_ACS_09_13           float64
#  148 Single_Unit_ACS_09_13             float64
#  149 MLT_U2_9_STRC_ACS_09_13           float64
#  150 MLT_U10p_ACS_09_13                float64
#  151 Mobile_Homes_ACS_09_13            float64
#  152 Crowd_Occp_U_ACS_09_13            float64
#  153 Occp_U_NO_PH_SRVC_ACS_09_13       float64
#  154 No_Plumb_ACS_09_13                float64
#  155 Recent_Built_HU_ACS_09_13         float64
#  156 Med_House_value_ACS_09_13         float64
#  157 Aggr_House_Value_ACS_09_13        float64
#  158 MailBack_Area_Count_CEN_2010      float64
#  159 TEA_Mail_Out_Mail_Back_CEN_2010   float64
#  160 TEA_Update_Leave_CEN_2010         float64
#  161 Census_Mail_Returns_CEN_2010      float64
#  162 Vacants_CEN_2010                  float64
#  163 Deletes_CEN_2010                  float64
#  164 Census_UAA_CEN_2010               float64
#  165 Valid_Mailback_Count_CEN_2010     float64
#  166 FRST_FRMS_CEN_2010                float64
#  167 RPLCMNT_FRMS_CEN_2010             float64
#  168 BILQ_Mailout_count_CEN_2010       float64
#  169 BILQ_Frms_CEN_2010                float64
#  170 Mail_Return_Rate_CEN_2010         float64
#  171 Low_Response_Score                float64
#  172 pct_URBANIZED_AREA_POP_CEN_2010   float64
#  173 pct_URBAN_CLUSTER_POP_CEN_2010    float64
#  174 pct_RURAL_POP_CEN_2010            float64
#  175 pct_Males_CEN_2010                float64
#  176 pct_Males_ACS_09_13               float64
#  177 pct_Females_CEN_2010              float64
#  178 pct_Females_ACS_09_13             float64
#  179 pct_Pop_Under_5_CEN_2010          float64
#  180 pct_Pop_Under_5_ACS_09_13         float64
#  181 pct_Pop_5_17_CEN_2010             float64
#  182 pct_Pop_5_17_ACS_09_13            float64
#  183 pct_Pop_18_24_CEN_2010            float64
#  184 pct_Pop_18_24_ACS_09_13           float64
#  185 pct_Pop_25_44_CEN_2010            float64
#  186 pct_Pop_25_44_ACS_09_13           float64
#  187 pct_Pop_45_64_CEN_2010            float64
#  188 pct_Pop_45_64_ACS_09_13           float64
#  189 pct_Pop_65plus_CEN_2010           float64
#  190 pct_Pop_65plus_ACS_09_13          float64
#  191 pct_Tot_GQ_CEN_2010               float64
#  192 pct_Inst_GQ_CEN_2010              float64
#  193 pct_Non_Inst_GQ_CEN_2010          float64
#  194 pct_Hispanic_CEN_2010             float64
#  195 pct_Hispanic_ACS_09_13            float64
#  196 pct_NH_White_alone_CEN_2010       float64
#  197 pct_NH_White_alone_ACS_09_13      float64
#  198 pct_NH_Blk_alone_CEN_2010         float64
#  199 pct_NH_Blk_alone_ACS_09_13        float64
#  200 pct_NH_AIAN_alone_CEN_2010        float64
#  201 pct_NH_AIAN_alone_ACS_09_13       float64
#  202 pct_NH_Asian_alone_CEN_2010       float64
#  203 pct_NH_Asian_alone_ACS_09_13      float64
#  204 pct_NH_NHOPI_alone_CEN_2010       float64
#  205 pct_NH_NHOPI_alone_ACS_09_13      float64
#  206 pct_NH_SOR_alone_CEN_2010         float64
#  207 pct_NH_SOR_alone_ACS_09_13        float64
#  208 pct_Pop_5yrs_Over_ACS_09_13       float64
#  209 pct_Othr_Lang_ACS_09_13           float64
#  210 pct_Age5p_Only_Eng_ACS_09_13      float64
#  211 pct_Age5p_Spanish_ACS_09_13       float64
#  212 pct_Age5p_French_ACS_09_13        float64
#  213 pct_Age5p_FrCreole_ACS_09_13      float64
#  214 pct_Age5p_Italian_ACS_09_13       float64
#  215 pct_Age5p_Portugues_ACS_09_13     float64
#  216 pct_Age5p_German_ACS_09_13        float64
#  217 pct_Age5p_Yiddish_ACS_09_13       float64
#  218 pct_Age5p_WGerman_ACS_09_13       float64
#  219 pct_Age5p_Scandinav_ACS_09_13     float64
#  220 pct_Age5p_Greek_ACS_09_13         float64
#  221 pct_Age5p_Russian_ACS_09_13       float64
#  222 pct_Age5p_Polish_ACS_09_13        float64
#  223 pct_Age5p_SRBCroati_ACS_09_13     float64
#  224 pct_Age5p_OthSlavic_ACS_09_13     float64
#  225 pct_Age5p_Armenian_ACS_09_13      float64
#  226 pct_Age5p_Persian_ACS_09_13       float64
#  227 pct_Age5p_Gujarati_ACS_09_13      float64
#  228 pct_Age5p_Hindi_ACS_09_13         float64
#  229 pct_Age5p_Urdu_ACS_09_13          float64
#  230 pct_Age5p_OthIndic_ACS_09_13      float64
#  231 pct_Age5p_OthEuro_ACS_09_13       float64
#  232 pct_Age5p_Chinese_ACS_09_13       float64
#  233 pct_Age5p_Japanese_ACS_09_13      float64
#  234 pct_Age5p_Korean_ACS_09_13        float64
#  235 pct_Age5p_Cambodian_ACS_09_13     float64
#  236 pct_Age5p_Hmong_ACS_09_13         float64
#  237 pct_Age5p_Thai_ACS_09_13          float64
#  238 pct_Age5p_Laotian_ACS_09_13       float64
#  239 pct_Age5p_Vietnames_ACS_09_13     float64
#  240 pct_Age5p_OthAsian_ACS_09_13      float64
#  241 pct_Age5p_Tagalog_ACS_09_13       float64
#  242 pct_Age5p_OthPacIsl_ACS_09_13     float64
#  243 pct_Age5p_Navajo_ACS_09_13        float64
#  244 pct_Age5p_NativeNAm_ACS_09_13     float64
#  245 pct_Age5p_Hungarian_ACS_09_13     float64
#  246 pct_Age5p_Arabic_ACS_09_13        float64
#  247 pct_Age5p_Hebrew_ACS_09_13        float64
#  248 pct_Age5p_African_ACS_09_13       float64
#  249 pct_Age5p_OthUnSp_ACS_09_13       float64
#  250 pct_Pop_25yrs_Over_ACS_09_13      float64
#  251 pct_Not_HS_Grad_ACS_09_13         float64
#  252 pct_College_ACS_09_13             float64
#  253 pct_Pov_Univ_ACS_09_13            float64
#  254 pct_Prs_Blw_Pov_Lev_ACS_09_13     float64
#  255 pct_One_Health_Ins_ACS_09_13      float64
#  256 pct_TwoPHealth_Ins_ACS_09_13      float64
#  257 pct_No_Health_Ins_ACS_09_13       float64
#  258 pct_Civ_emp_16p_ACS_09_13         float64
#  259 pct_Civ_unemp_16p_ACS_09_13       float64
#  260 pct_Civ_emp_16_24_ACS_09_13       float64
#  261 pct_Civ_unemp_16_24_ACS_09_13     float64
#  262 pct_Civ_emp_25_44_ACS_09_13       float64
#  263 pct_Civ_unemp_25_44_ACS_09_13     float64
#  264 pct_Civ_emp_45_64_ACS_09_13       float64
#  265 pct_Civ_unemp_45_64_ACS_09_13     float64
#  266 pct_Civ_emp_65p_ACS_09_13         float64
#  267 pct_Civ_unemp_65p_ACS_09_13       float64
#  268 pct_Pop_1yr_Over_ACS_09_13        float64
#  269 pct_Diff_HU_1yr_Ago_ACS_09_13     float64
#  270 pct_Born_US_ACS_09_13             float64
#  271 pct_Born_foreign_ACS_09_13        float64
#  272 pct_US_Cit_Nat_ACS_09_13          float64
#  273 pct_NON_US_Cit_ACS_09_13          float64
#  274 pct_ENG_VW_SPAN_ACS_09_13         float64
#  275 pct_ENG_VW_INDOEURO_ACS_09_13     float64
#  276 pct_ENG_VW_API_ACS_09_13          float64
#  277 pct_ENG_VW_OTHER_ACS_09_13        float64
#  278 pct_ENG_VW_ACS_09_13              float64
#  279 pct_Rel_Family_HHDS_CEN_2010      float64
#  280 pct_Rel_Family_HHD_ACS_09_13      float64
#  281 pct_MrdCple_HHD_CEN_2010          float64
#  282 pct_MrdCple_HHD_ACS_09_13         float64
#  283 pct_Not_MrdCple_HHD_CEN_2010      float64
#  284 pct_Not_MrdCple_HHD_ACS_09_13     float64
#  285 pct_Female_No_HB_CEN_2010         float64
#  286 pct_Female_No_HB_ACS_09_13        float64
#  287 pct_NonFamily_HHD_CEN_2010        float64
#  288 pct_NonFamily_HHD_ACS_09_13       float64
#  289 pct_Sngl_Prns_HHD_CEN_2010        float64
#  290 pct_Sngl_Prns_HHD_ACS_09_13       float64
#  291 pct_HHD_PPL_Und_18_CEN_2010       float64
#  292 pct_HHD_PPL_Und_18_ACS_09_13      float64
#  293 avg_Tot_Prns_in_HHD_CEN_2010      float64
#  294 avg_Tot_Prns_in_HHD_ACS_09_13     float64
#  295 pct_Rel_Under_6_CEN_2010          float64
#  296 pct_Rel_Under_6_ACS_09_13         float64
#  297 pct_HHD_Moved_in_ACS_09_13        float64
#  298 pct_PUB_ASST_INC_ACS_09_13        float64
#  299 avg_Agg_HH_INC_ACS_09_13          float64
#  300 pct_Tot_Occp_Units_CEN_2010       float64
#  301 pct_Tot_Occp_Units_ACS_09_13      float64
#  302 pct_Vacant_Units_CEN_2010         float64
#  303 pct_Vacant_Units_ACS_09_13        float64
#  304 pct_Renter_Occp_HU_CEN_2010       float64
#  305 pct_Renter_Occp_HU_ACS_09_13      float64
#  306 pct_Owner_Occp_HU_CEN_2010        float64
#  307 pct_Owner_Occp_HU_ACS_09_13       float64
#  308 pct_Single_Unit_ACS_09_13         float64
#  309 pct_MLT_U2_9_STRC_ACS_09_13       float64
#  310 pct_MLT_U10p_ACS_09_13            float64
#  311 pct_Mobile_Homes_ACS_09_13        float64
#  312 pct_Crowd_Occp_U_ACS_09_13        float64
#  313 pct_NO_PH_SRVC_ACS_09_13          float64
#  314 pct_No_Plumb_ACS_09_13            float64
#  315 pct_Recent_Built_HU_ACS_09_13     float64
#  316 avg_Agg_House_Value_ACS_09_13     float64
#  317 pct_TEA_MailOutMailBack_CEN_2010  float64
#  318 pct_TEA_Update_Leave_CEN_2010     float64
#  319 pct_Census_Mail_Returns_CEN_2010  float64
#  320 pct_Vacant_CEN_2010               float64
#  321 pct_Deletes_CEN_2010              float64
#  322 pct_Census_UAA_CEN_2010           float64
#  323 pct_Mailback_Count_CEN_2010       float64
#  324 pct_FRST_FRMS_CEN_2010            float64
#  325 pct_RPLCMNT_FRMS_CEN_2010         float64
#  326 pct_BILQ_Mailout_count_CEN_2010   float64
#  327 has_superfund                     int64
# dtypes: float64(327), int64(1)
# memory usage: 185.2 MB

# %% [markdown]
# ## Features selection through variance and correlation

# %%
# Normalize the variance and select only high variance columns above 0.1
sel = VarianceThreshold(threshold=0.1)

sel.fit(sf_tract/sf_tract.mean())

mask = sel.get_support()

reduced_sf = sf_tract.loc[:, mask]

print(reduced_sf.shape)
# Out:
# (74021, 294)

# %% [markdown]
# We able to delete 34 low variance features but we still have almost 300 features to simplify more

# %%
# Remove highly correlated features
# Create positive correlation matrix
corr_sf = reduced_sf.corr().abs()

# Create a mask matrix
mask = np.triu(np.ones_like(corr_sf, dtype=bool))

# %%
# Apply the mask to our correlation matrix
tri_sf = corr_sf.mask(mask)

tri_sf
# Out:
#                                  LAND_AREA  AIAN_LAND  \
# LAND_AREA                              NaN        NaN
# AIAN_LAND                         0.138494        NaN
# URBANIZED_AREA_POP_CEN_2010       0.097833   0.115712
# URBAN_CLUSTER_POP_CEN_2010        0.000938   0.083958
# RURAL_POP_CEN_2010                0.126386   0.134151
# ...                                    ...        ...
# pct_Deletes_CEN_2010              0.232142   0.093368
# pct_Census_UAA_CEN_2010           0.013447   0.010064
# pct_RPLCMNT_FRMS_CEN_2010         0.074072   0.006048
# pct_BILQ_Mailout_count_CEN_2010   0.033593   0.041169
# has_superfund                     0.002936   0.002056
#
#                                  URBANIZED_AREA_POP_CEN_2010  \
# LAND_AREA                                                NaN
# AIAN_LAND                                                NaN
# URBANIZED_AREA_POP_CEN_2010                              NaN
# URBAN_CLUSTER_POP_CEN_2010                          0.395151
# RURAL_POP_CEN_2010                                  0.508525
# ...                                                      ...
# pct_Deletes_CEN_2010                                0.186264
# pct_Census_UAA_CEN_2010                             0.242361
# pct_RPLCMNT_FRMS_CEN_2010                           0.011521
# pct_BILQ_Mailout_count_CEN_2010                     0.160551
# has_superfund                                       0.012896
#
#                                  URBAN_CLUSTER_POP_CEN_2010  \
# LAND_AREA                                               NaN
# AIAN_LAND                                               NaN
# URBANIZED_AREA_POP_CEN_2010                             NaN
# URBAN_CLUSTER_POP_CEN_2010                              NaN
# RURAL_POP_CEN_2010                                 0.052665
# ...                                                     ...
# pct_Deletes_CEN_2010                               0.026366
# pct_Census_UAA_CEN_2010                            0.065845
# pct_RPLCMNT_FRMS_CEN_2010                          0.010686
# pct_BILQ_Mailout_count_CEN_2010                    0.033900
# has_superfund                                      0.029735
#
#                                  RURAL_POP_CEN_2010  Tot_Population_CEN_2010  \
# LAND_AREA                                       NaN                      NaN
# AIAN_LAND                                       NaN                      NaN
# URBANIZED_AREA_POP_CEN_2010                     NaN                      NaN
# URBAN_CLUSTER_POP_CEN_2010                      NaN                      NaN
# RURAL_POP_CEN_2010                              NaN                      NaN
# ...                                             ...                      ...
# pct_Deletes_CEN_2010                       0.200614                 0.064649
# pct_Census_UAA_CEN_2010                    0.149966                 0.150913
# pct_RPLCMNT_FRMS_CEN_2010                  0.104436                 0.073131
# pct_BILQ_Mailout_count_CEN_2010            0.150169                 0.066488
# has_superfund                              0.023155                 0.019585
#
#                                  Tot_Population_ACS_09_13  Males_CEN_2010  \
# LAND_AREA                                             NaN             NaN
# AIAN_LAND                                             NaN             NaN
# URBANIZED_AREA_POP_CEN_2010                           NaN             NaN
# URBAN_CLUSTER_POP_CEN_2010                            NaN             NaN
# RURAL_POP_CEN_2010                                    NaN             NaN
# ...                                                   ...             ...
# pct_Deletes_CEN_2010                             0.072610        0.048771
# pct_Census_UAA_CEN_2010                          0.150741        0.133859
# pct_RPLCMNT_FRMS_CEN_2010                        0.073484        0.068739
# pct_BILQ_Mailout_count_CEN_2010                  0.065078        0.079626
# has_superfund                                    0.018496        0.024502
#
#                                  Males_ACS_09_13  Females_CEN_2010  ...  \
# LAND_AREA                                    NaN               NaN  ...
# AIAN_LAND                                    NaN               NaN  ...
# URBANIZED_AREA_POP_CEN_2010                  NaN               NaN  ...
# URBAN_CLUSTER_POP_CEN_2010                   NaN               NaN  ...
# RURAL_POP_CEN_2010                           NaN               NaN  ...
# ...                                          ...               ...  ...
# pct_Deletes_CEN_2010                    0.059225          0.078448  ...
# pct_Census_UAA_CEN_2010                 0.135862          0.163503  ...
# pct_RPLCMNT_FRMS_CEN_2010               0.071325          0.075435  ...
# pct_BILQ_Mailout_count_CEN_2010         0.076216          0.051787  ...
# has_superfund                           0.024330          0.014184  ...
#
#                                  pct_No_Plumb_ACS_09_13  \
# LAND_AREA                                           NaN
# AIAN_LAND                                           NaN
# URBANIZED_AREA_POP_CEN_2010                         NaN
# URBAN_CLUSTER_POP_CEN_2010                          NaN
# RURAL_POP_CEN_2010                                  NaN
# ...                                                 ...
# pct_Deletes_CEN_2010                           0.221844
# pct_Census_UAA_CEN_2010                        0.293767
# pct_RPLCMNT_FRMS_CEN_2010                      0.123624
# pct_BILQ_Mailout_count_CEN_2010                0.000939
# has_superfund                                  0.001944
#
#                                  pct_Recent_Built_HU_ACS_09_13  \
# LAND_AREA                                                  NaN
# AIAN_LAND                                                  NaN
# URBANIZED_AREA_POP_CEN_2010                                NaN
# URBAN_CLUSTER_POP_CEN_2010                                 NaN
# RURAL_POP_CEN_2010                                         NaN
# ...                                                        ...
# pct_Deletes_CEN_2010                                  0.018899
# pct_Census_UAA_CEN_2010                               0.041144
# pct_RPLCMNT_FRMS_CEN_2010                             0.019189
# pct_BILQ_Mailout_count_CEN_2010                       0.027021
# has_superfund                                         0.008184
#
#                                  avg_Agg_House_Value_ACS_09_13  \
# LAND_AREA                                                  NaN
# AIAN_LAND                                                  NaN
# URBANIZED_AREA_POP_CEN_2010                                NaN
# URBAN_CLUSTER_POP_CEN_2010                                 NaN
# RURAL_POP_CEN_2010                                         NaN
# ...                                                        ...
# pct_Deletes_CEN_2010                                  0.058307
# pct_Census_UAA_CEN_2010                               0.186868
# pct_RPLCMNT_FRMS_CEN_2010                             0.195700
# pct_BILQ_Mailout_count_CEN_2010                       0.127203
# has_superfund                                         0.007503
#
#                                  pct_TEA_Update_Leave_CEN_2010  \
# LAND_AREA                                                  NaN
# AIAN_LAND                                                  NaN
# URBANIZED_AREA_POP_CEN_2010                                NaN
# URBAN_CLUSTER_POP_CEN_2010                                 NaN
# RURAL_POP_CEN_2010                                         NaN
# ...                                                        ...
# pct_Deletes_CEN_2010                                  0.557772
# pct_Census_UAA_CEN_2010                               0.241292
# pct_RPLCMNT_FRMS_CEN_2010                             0.218925
# pct_BILQ_Mailout_count_CEN_2010                       0.060406
# has_superfund                                         0.006607
#
#                                  pct_Vacant_CEN_2010  pct_Deletes_CEN_2010  \
# LAND_AREA                                        NaN                   NaN
# AIAN_LAND                                        NaN                   NaN
# URBANIZED_AREA_POP_CEN_2010                      NaN                   NaN
# URBAN_CLUSTER_POP_CEN_2010                       NaN                   NaN
# RURAL_POP_CEN_2010                               NaN                   NaN
# ...                                              ...                   ...
# pct_Deletes_CEN_2010                        0.417008                   NaN
# pct_Census_UAA_CEN_2010                     0.118135              0.168444
# pct_RPLCMNT_FRMS_CEN_2010                   0.049749              0.142718
# pct_BILQ_Mailout_count_CEN_2010             0.022173              0.037464
# has_superfund                               0.004424              0.000725
#
#                                  pct_Census_UAA_CEN_2010  \
# LAND_AREA                                            NaN
# AIAN_LAND                                            NaN
# URBANIZED_AREA_POP_CEN_2010                          NaN
# URBAN_CLUSTER_POP_CEN_2010                           NaN
# RURAL_POP_CEN_2010                                   NaN
# ...                                                  ...
# pct_Deletes_CEN_2010                                 NaN
# pct_Census_UAA_CEN_2010                              NaN
# pct_RPLCMNT_FRMS_CEN_2010                       0.292236
# pct_BILQ_Mailout_count_CEN_2010                 0.035702
# has_superfund                                   0.016532
#
#                                  pct_RPLCMNT_FRMS_CEN_2010  \
# LAND_AREA                                              NaN
# AIAN_LAND                                              NaN
# URBANIZED_AREA_POP_CEN_2010                            NaN
# URBAN_CLUSTER_POP_CEN_2010                             NaN
# RURAL_POP_CEN_2010                                     NaN
# ...                                                    ...
# pct_Deletes_CEN_2010                                   NaN
# pct_Census_UAA_CEN_2010                                NaN
# pct_RPLCMNT_FRMS_CEN_2010                              NaN
# pct_BILQ_Mailout_count_CEN_2010                   0.137980
# has_superfund                                     0.001546
#
#                                  pct_BILQ_Mailout_count_CEN_2010  \
# LAND_AREA                                                    NaN
# AIAN_LAND                                                    NaN
# URBANIZED_AREA_POP_CEN_2010                                  NaN
# URBAN_CLUSTER_POP_CEN_2010                                   NaN
# RURAL_POP_CEN_2010                                           NaN
# ...                                                          ...
# pct_Deletes_CEN_2010                                         NaN
# pct_Census_UAA_CEN_2010                                      NaN
# pct_RPLCMNT_FRMS_CEN_2010                                    NaN
# pct_BILQ_Mailout_count_CEN_2010                              NaN
# has_superfund                                           0.014193
#
#                                  has_superfund
# LAND_AREA                                  NaN
# AIAN_LAND                                  NaN
# URBANIZED_AREA_POP_CEN_2010                NaN
# URBAN_CLUSTER_POP_CEN_2010                 NaN
# RURAL_POP_CEN_2010                         NaN
# ...                                        ...
# pct_Deletes_CEN_2010                       NaN
# pct_Census_UAA_CEN_2010                    NaN
# pct_RPLCMNT_FRMS_CEN_2010                  NaN
# pct_BILQ_Mailout_count_CEN_2010            NaN
# has_superfund                              NaN
#
# [294 rows x 294 columns]

# %%
# Find columns that meet threshold
to_drop = [c for c in tri_sf.columns if any(tri_sf[c] > 0.7)]

# Drop those columns
reduced_sf = reduced_sf.drop(to_drop, axis=1)

reduced_sf.shape
# Out:
# (74021, 93)

# %% [markdown]
# We see that we are able to drop from 294 columns to 93 columns that have correlation with each other below 0.7

# %%
# We have imbalance classes with missing values only in one majority class so it is safe to delete those missing rows
# Further, will still have 93% of original dataset after dropping these rows rather than imputing
reduced_sf = reduced_sf.dropna(how='any')

reduced_sf.shape
# Out:
# (68776, 93)

# %% [markdown]
# ## Dealing with imbalanced classes

# %%
# Seperate input features and target
X = reduced_sf.drop('has_superfund', axis=1)
y = reduced_sf['has_superfund']

# %%
# Summarize class distribution
counter = Counter(y)

print(counter)
# Out:
# Counter({0: 67633, 1: 1143})

# %% [markdown]
# #### Decision tree evaluated on imbalanced dataset

# %%
# Define model
model = DecisionTreeClassifier()
# Evaluate pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.505

# %% [markdown]
# We see that the classification perfom just like a random guess at 50% on this extreme imbalanced dataset

# %% [markdown]
# #### Borderline-SMOTE

# %%
# Transform the dataset
oversample = BorderlineSMOTE()
X, y = oversample.fit_resample(X, y)
# Summarize the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 67633, 1: 67633})

# %%
# Define model
model = DecisionTreeClassifier()
# Evaluate pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.971

# %% [markdown]
# #### Borderline-SMOTE SVM

# %%
# Re-seperate input features and target
X = reduced_sf.drop('has_superfund', axis=1)
y = reduced_sf['has_superfund']

# Summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 67633, 1: 1143})

# %%
# transform the dataset
oversample = SVMSMOTE()
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 67633, 1: 34232})

# %%
# Define model
model = DecisionTreeClassifier()
# Evaluate pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.962

# %% [markdown]
# #### Adaptive Synthetic Sampling (ADASYN)

# %%
# Re-seperate input features and target
X = reduced_sf.drop('has_superfund', axis=1)
y = reduced_sf['has_superfund']

# Summarize class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 67633, 1: 1143})

# %%
# transform the dataset
oversample = ADASYN()
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# Out:
# Counter({0: 67633, 1: 67275})

# %%
# Define model
model = DecisionTreeClassifier()
# Evaluate pipeline
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
print('Mean ROC AUC: %.3f' % mean(scores))
# Out:
# Mean ROC AUC: 0.951

# %% [markdown]
# Among three different methods of resampling the dataset, Borderline-SMOTE gave us the best performance so we will resample the Census dataset using this method

# %% [markdown]
# #### Create a balanced class dataset

# %%
# Re-seperate input features and target
X = reduced_sf.drop('has_superfund', axis=1)
y = reduced_sf['has_superfund']

# Transform the dataset
oversample = BorderlineSMOTE()
X, y = oversample.fit_resample(X, y)
# Out:
# Mean ROC AUC: 0.971

# %%
# Save a copy of this full X,y
X1 = X
y1 = y

# %% [markdown]
# ## Selecting features for model performance

# %%
# Pre-processing the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_std = scaler.fit_transform(X_train)

# %% [markdown]
# #### Creating a logistic regression model

# %%
lr = LogisticRegression()
lr.fit(X_train_std, y_train)

X_test_std = scaler.transform(X_test)

y_pred = lr.predict(X_test_std)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.6703548546081813

# %% [markdown]
# #### Recursive Feature Elimination with Logistic Regression

# %%
from sklearn.feature_selection import RFE

rfe = RFE(estimator=LogisticRegression(), n_features_to_select=10)

rfe.fit(X_train_std, y_train)
# Out:
# RFE(estimator=LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                  fit_intercept=True, intercept_scaling=1,
#                                  l1_ratio=None, max_iter=100,
#                                  multi_class='auto', n_jobs=None, penalty='l2',
#                                  random_state=None, solver='lbfgs', tol=0.0001,
#                                  verbose=0, warm_start=False),
#     n_features_to_select=10, step=1, verbose=0)

# %%
# Inspecting the RFE results
X.columns[rfe.support_]
# Out:
# Index(['Age5p_Italian_ACS_09_13', 'Age5p_OthEuro_ACS_09_13',
#        'Civ_unemp_45_64_ACS_09_13', 'pct_URBAN_CLUSTER_POP_CEN_2010',
#        'pct_Age5p_Italian_ACS_09_13', 'pct_Age5p_Yiddish_ACS_09_13',
#        'pct_Age5p_OthEuro_ACS_09_13', 'pct_Civ_unemp_45_64_ACS_09_13',
#        'pct_Diff_HU_1yr_Ago_ACS_09_13', 'avg_Agg_House_Value_ACS_09_13'],
#       dtype='object')

# %%
print(accuracy_score(y_test, rfe.predict(X_test_std)))
# Out:
# 0.6436914736323311

# %% [markdown]
# #### Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

rf.fit(X_train, y_train)

print(accuracy_score(y_test, rf.predict(X_test)))
# Out:
# 0.9907836372597338

# %% [markdown]
# #### RFE with Random Forest

# %%
rfe = RFE(estimator=RandomForestClassifier(), n_features_to_select=10)

rfe.fit(X_train, y_train)

print(X.columns[rfe.support_])
# Out:
# Index(['LAND_AREA', 'FRST_FRMS_CEN_2010', 'pct_RURAL_POP_CEN_2010',
#        'pct_Non_Inst_GQ_CEN_2010', 'pct_NH_AIAN_alone_ACS_09_13',
#        'pct_NH_SOR_alone_CEN_2010', 'pct_MLT_U10p_ACS_09_13',
#        'pct_Mobile_Homes_ACS_09_13', 'pct_No_Plumb_ACS_09_13',
#        'avg_Agg_House_Value_ACS_09_13'],
#       dtype='object')

# %%
print(accuracy_score(y_test, rfe.predict(X_test)))
# Out:
# 0.9831690487925087

# %% [markdown]
# We see that by using only 10 features out of 567 original feautures, we can predict the status of Superfund with 98% accuracy on a balanced class dataset. If we want to achieve 99% accuracy then we need to use a total of 93 features out of 567 original features.
